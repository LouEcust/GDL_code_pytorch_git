# %% [markdown]
# # VAE Training - Faces dataset

# %%
import torch as t
import torch.nn.functional as F
import zipfile
import os
from tqdm import tqdm
from models.CelebVariationalAutoencoder import CelebVariationalAutoencoder
from utils.data.FaceDataset import FaceDataset
from google_drive_downloader import GoogleDriveDownloader as gdd


# this will take some time :), its 1.3gb to download
faces_zip = 'data/faces.zip'
if not os.path.exists(faces_zip):
    gdd.download_file_from_google_drive(file_id='0B7EVK8r0v71pZjFTYXZWM3FlRnM',
                                        dest_path=faces_zip)
    gdd.download_file_from_google_drive()
    with zipfile.ZipFile(faces_zip, 'r') as zip_ref:
        zip_ref.extractall('data/faces')

bs = 64
train_ds = FaceDataset("data/faces/img_align_celeba/")
train_dl = t.utils.data.DataLoader(dataset=train_ds, batch_size=bs, shuffle=True, drop_last=True)

device = t.device('cuda') if t.cuda.is_available() else 'cpu'
model = CelebVariationalAutoencoder(train_ds[0][0][None], in_c=3, enc_out_c=[32, 64, 64, 64],
                               enc_ks=[3, 3, 3, 3], enc_pads=[1, 1, 0, 1], enc_strides=[1, 2, 2, 1],
                               dec_out_c=[64, 64, 32, 3], dec_ks=[3, 3, 3, 3], dec_strides=[1, 2, 2, 1],
                               dec_pads=[1, 0, 1, 1], dec_op_pads=[0, 1, 1, 0], z_dim=200)
model.cuda(device)
model.train()
# Out:
# Downloading 0B7EVK8r0v71pZjFTYXZWM3FlRnM into data/faces.zip...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7efde7850130>: Failed to establish a new connection: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='docs.google.com', port=443): Max retries exceeded with url: /uc?export=download&id=0B7EVK8r0v71pZjFTYXZWM3FlRnM (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7efde7850130>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /tmp/ipykernel_12962/2030612316.py in <module>
#      12 faces_zip = 'data/faces.zip'
#      13 if not os.path.exists(faces_zip):
# ---> 14     gdd.download_file_from_google_drive(file_id='0B7EVK8r0v71pZjFTYXZWM3FlRnM',
#      15                                         dest_path=faces_zip)
#      16     gdd.download_file_from_google_drive()
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/googledrivedownloader-0.4-py3.8.egg/google_drive_downloader/google_drive_downloader.py in download_file_from_google_drive(file_id, dest_path, overwrite, unzip, showsize)
#      54             stdout.flush()
#      55
# ---> 56             response = session.get(GoogleDriveDownloader.DOWNLOAD_URL, params={'id': file_id}, stream=True)
#      57
#      58             token = GoogleDriveDownloader._get_confirm_token(response)
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/ljhpy/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='docs.google.com', port=443): Max retries exceeded with url: /uc?export=download&id=0B7EVK8r0v71pZjFTYXZWM3FlRnM (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7efde7850130>: Failed to establish a new connection: [Errno 101] Network is unreachable'))

# %%
def vae_kl_loss(mu, log_var):
    return -.5 * t.sum(1 + log_var - mu ** 2 - log_var.exp())

def vae_loss(y_pred, mu, log_var, y_true, r_loss_factor=1000):
    r_loss = F.binary_cross_entropy(y_pred, y_true, reduction='sum')
    kl_loss = vae_kl_loss(mu, log_var)
    return r_loss_factor * r_loss + kl_loss

lr = .0005
for epoch in tqdm(range(3)):
    optimizer = t.optim.Adam(model.parameters(), lr=lr / (epoch * 2 + 1), betas=(.9, .99), weight_decay=1e-2)
    for i, (data, _) in enumerate(train_dl):
        data = data.to(device)
        optimizer.zero_grad()
        pred, mu, log_var = model(data)
        loss = vae_loss(pred, mu, log_var, data)
        loss.backward()
        t.nn.utils.clip_grad_norm_(model.parameters(), .25)  # 梯度裁剪，如果网络所有梯度的2范数之和超过0.25，则使其归一化为0.25
        optimizer.step()
        if i % 33 == 0:
            print(loss / bs)

print(loss)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25891590., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26222378., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25820694., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26800756., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26672304., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26625590., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26565336., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26885380., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26404840., device='cuda:0', grad_fn=<DivBackward0>)
# 100%|██████████| 3/3 [1:19:28<00:00, 1593.57s/it]
# tensor(1657669632., device='cuda:0', grad_fn=<AddBackward0>)

# %%
t.save(model.state_dict(), 'models/state_dicts/03_05.pth')

# %%
lr = .0005
for epoch in tqdm(range(3, 5)):
    optimizer = t.optim.Adam(model.parameters(), lr=lr / (epoch * 2 + 1), betas=(.9, .99), weight_decay=1e-2)
    for i, (data, _) in enumerate(train_dl):
        data = data.to(device)
        optimizer.zero_grad()
        pred, mu, log_var = model(data)
        loss = vae_loss(pred, mu, log_var, data)
        loss.backward()
        t.nn.utils.clip_grad_norm_(model.parameters(), .25)
        optimizer.step()
        if i % 33 == 0:
            print(loss / bs)

print(loss)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# tensor(26122478., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26074100., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25833470., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26289132., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26832608., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26591926., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26524614., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26615118., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(27162468., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26599992., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26118604., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26165174., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26279220., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26323964., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26328696., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26620050., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26036438., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25246744., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26836970., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25494254., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26225494., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26293198., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26322108., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26788000., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26184946., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26335274., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26283558., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(27065532., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26230236., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26593868., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25674768., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26314638., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26858398., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25940904., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26429268., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25854760., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(27097696., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26558422., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(27114802., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26557290., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25551676., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26410144., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26448782., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26361246., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26217178., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26430666., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26159936., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26373250., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25818872., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26003754., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25880670., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26245548., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26031422., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25932160., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26389632., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25945974., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26067560., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26077414., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26181338., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26628694., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25921818., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26358414., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26629940., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26760246., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26977702., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26430738., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26241870., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26061948., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26039070., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25459510., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26633108., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25790268., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26630734., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26372720., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25954780., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25631672., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25623856., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26408578., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25937178., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26577644., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26400248., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25848334., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25938550., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26171386., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25679722., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26444286., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26078518., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26240480., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26412424., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26939664., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25792186., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26330858., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26382954., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26302356., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26264756., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26708132., device='cuda:0', grad_fn=<DivBackward0>)
#  50%|█████     | 1/2 [26:45<26:45, 1605.57s/it]
# tensor(26394400., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26236288., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25804286., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26903614., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26662452., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26644092., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26373228., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26691236., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25686442., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26356246., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26791182., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25466834., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26669580., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26525412., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26029278., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25963376., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26508208., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26223580., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25858830., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26199308., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26541052., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26433484., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26176724., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26017448., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26222236., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26074008., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26490210., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26064384., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25480158., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26219554., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26386564., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26585404., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26309422., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26849358., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26542350., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25915976., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26135018., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26251626., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25932488., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26904350., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26461708., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25530004., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26248746., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(27078402., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25570268., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26136538., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26906690., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25590184., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25954088., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26775660., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26136854., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25659486., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25946472., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26944058., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26299664., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26612890., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26729534., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26856292., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25852402., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26520628., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26312244., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26743934., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26938210., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26499062., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26549576., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26304136., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25425808., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25931600., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25524336., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25462684., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26694384., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(27117980., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25768554., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25871436., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26660868., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25756176., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25665548., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(27297642., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26743802., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26446776., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26040122., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26209390., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26227144., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25951220., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26430186., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25947370., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26302596., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26672846., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26035884., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26825328., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25880072., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26364068., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26857122., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26762574., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(26888380., device='cuda:0', grad_fn=<DivBackward0>)
# tensor(25472702., device='cuda:0', grad_fn=<DivBackward0>)
# 100%|██████████| 2/2 [53:30<00:00, 1605.39s/it]
# tensor(1662345472., device='cuda:0', grad_fn=<AddBackward0>)

# %%
t.save(model.state_dict(), 'models/state_dict/03_05_full.pth')

# %%
loss / bs
# Out:
# tensor(25974148., device='cuda:0', grad_fn=<DivBackward0>)
